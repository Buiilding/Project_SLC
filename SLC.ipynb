# %%
conda install tensorflow
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Note: you may need to restart the kernel to use updated packages.
#
# Solving environment: ...working... failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: ...working... failed with repodata from current_repodata.json, will retry with next repodata source.
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\tuana\miniconda3
#
#   added / updated specs:
#     - tensorflow
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     abseil-cpp-20210324.2      |       hd77b12b_0         1.6 MB
#     absl-py-1.3.0              |   py39haa95532_0         171 KB
#     aiohttp-3.8.3              |   py39h2bbff1b_0         415 KB
#     astor-0.8.1                |   py39haa95532_0          47 KB
#     async-timeout-4.0.2        |   py39haa95532_0          12 KB
#     attrs-22.1.0               |   py39haa95532_0          84 KB
#     blinker-1.4                |   py39haa95532_0          23 KB
#     certifi-2022.12.7          |   py39haa95532_0         149 KB
#     click-8.0.4                |   py39haa95532_0         155 KB
#     conda-23.1.0               |   py39haa95532_0         946 KB
#     frozenlist-1.3.3           |   py39h2bbff1b_0          40 KB
#     google-auth-oauthlib-0.4.1 |             py_2          20 KB
#     grpcio-1.42.0              |   py39hc60d5dd_0         1.9 MB
#     h5py-3.7.0                 |   py39h3de5c98_0         823 KB
#     icu-68.1                   |       h6c2663c_0        11.0 MB
#     importlib-metadata-4.11.3  |   py39haa95532_0          41 KB
#     libprotobuf-3.14.0         |       h23ce68f_0         1.9 MB
#     markdown-3.4.1             |   py39haa95532_0         148 KB
#     markupsafe-2.1.1           |   py39h2bbff1b_0          26 KB
#     mkl-service-2.4.0          |   py39h2bbff1b_0          51 KB
#     mkl_fft-1.3.1              |   py39h277e83a_0         139 KB
#     mkl_random-1.2.2           |   py39hf11a4ad_0         225 KB
#     multidict-6.0.2            |   py39h2bbff1b_0          46 KB
#     numpy-1.23.5               |   py39h3b20f71_0          11 KB
#     numpy-base-1.23.5          |   py39h4da318b_0         6.0 MB
#     oauthlib-3.2.1             |   py39haa95532_0         194 KB
#     packaging-22.0             |   py39haa95532_0          67 KB
#     pluggy-1.0.0               |   py39haa95532_1          29 KB
#     protobuf-3.14.0            |   py39hd77b12b_1         241 KB
#     pyjwt-2.4.0                |   py39haa95532_0          38 KB
#     python-flatbuffers-1.12    |     pyhd3eb1b0_0          24 KB
#     ruamel.yaml-0.17.21        |   py39h2bbff1b_0         174 KB
#     ruamel.yaml.clib-0.2.6     |   py39h2bbff1b_1         101 KB
#     scipy-1.10.0               |   py39h321e85e_0        18.7 MB
#     tensorboard-2.6.0          |             py_1         4.9 MB
#     tensorboard-data-server-0.6.1|   py39haa95532_0          17 KB
#     tensorboard-plugin-wit-1.8.1|   py39haa95532_0         671 KB
#     tensorflow-2.6.0           |mkl_py39h31650da_0           4 KB
#     tensorflow-base-2.6.0      |mkl_py39h9201259_0        65.1 MB
#     tensorflow-estimator-2.6.0 |     pyh7b7c402_0         267 KB
#     termcolor-2.1.0            |   py39haa95532_0          12 KB
#     toolz-0.12.0               |   py39haa95532_0         106 KB
#     typing_extensions-4.4.0    |   py39haa95532_0          47 KB
#     werkzeug-2.2.2             |   py39haa95532_0         340 KB
#     wheel-0.35.1               |     pyhd3eb1b0_0          38 KB
#     wrapt-1.14.1               |   py39h2bbff1b_0          49 KB
#     yarl-1.8.1                 |   py39h2bbff1b_0          80 KB
#     zipp-3.11.0                |   py39haa95532_0          20 KB
#     ------------------------------------------------------------
#                                            Total:       117.0 MB
#
# The following NEW packages will be INSTALLED:
#
#   _tflow_select      pkgs/main/win-64::_tflow_select-2.3.0-mkl
#   abseil-cpp         pkgs/main/win-64::abseil-cpp-20210324.2-hd77b12b_0
#   absl-py            pkgs/main/win-64::absl-py-1.3.0-py39haa95532_0
#   aiohttp            pkgs/main/win-64::aiohttp-3.8.3-py39h2bbff1b_0
#   aiosignal          pkgs/main/noarch::aiosignal-1.2.0-pyhd3eb1b0_0
#   appdirs            pkgs/main/noarch::appdirs-1.4.4-pyhd3eb1b0_0
#   astor              pkgs/main/win-64::astor-0.8.1-py39haa95532_0
#   astunparse         pkgs/main/noarch::astunparse-1.6.3-py_0
#   async-timeout      pkgs/main/win-64::async-timeout-4.0.2-py39haa95532_0
#   attrs              pkgs/main/win-64::attrs-22.1.0-py39haa95532_0
#   blas               pkgs/main/win-64::blas-1.0-mkl
#   blinker            pkgs/main/win-64::blinker-1.4-py39haa95532_0
#   cachetools         pkgs/main/noarch::cachetools-4.2.2-pyhd3eb1b0_0
#   click              pkgs/main/win-64::click-8.0.4-py39haa95532_0
#   fftw               pkgs/main/win-64::fftw-3.3.9-h2bbff1b_1
#   flatbuffers        pkgs/main/win-64::flatbuffers-2.0.0-h6c2663c_0
#   flit-core          pkgs/main/noarch::flit-core-3.6.0-pyhd3eb1b0_0
#   frozenlist         pkgs/main/win-64::frozenlist-1.3.3-py39h2bbff1b_0
#   gast               pkgs/main/noarch::gast-0.4.0-pyhd3eb1b0_0
#   giflib             pkgs/main/win-64::giflib-5.2.1-h8cc25b3_1
#   google-auth        pkgs/main/noarch::google-auth-2.6.0-pyhd3eb1b0_0
#   google-auth-oauth~ pkgs/main/noarch::google-auth-oauthlib-0.4.1-py_2
#   google-pasta       pkgs/main/noarch::google-pasta-0.2.0-pyhd3eb1b0_0
#   grpcio             pkgs/main/win-64::grpcio-1.42.0-py39hc60d5dd_0
#   h5py               pkgs/main/win-64::h5py-3.7.0-py39h3de5c98_0
#   hdf5               pkgs/main/win-64::hdf5-1.10.6-h1756f20_1
#   icc_rt             pkgs/main/win-64::icc_rt-2022.1.0-h6049295_2
#   icu                pkgs/main/win-64::icu-68.1-h6c2663c_0
#   importlib-metadata pkgs/main/win-64::importlib-metadata-4.11.3-py39haa95532_0
#   intel-openmp       pkgs/main/win-64::intel-openmp-2021.4.0-haa95532_3556
#   jpeg               pkgs/main/win-64::jpeg-9e-h2bbff1b_0
#   keras-preprocessi~ pkgs/main/noarch::keras-preprocessing-1.1.2-pyhd3eb1b0_0
#   libcurl            pkgs/main/win-64::libcurl-7.87.0-h86230a5_0
#   libpng             pkgs/main/win-64::libpng-1.6.37-h2a8f88b_0
#   libprotobuf        pkgs/main/win-64::libprotobuf-3.14.0-h23ce68f_0
#   libssh2            pkgs/main/win-64::libssh2-1.10.0-hcd4344a_0
#   markdown           pkgs/main/win-64::markdown-3.4.1-py39haa95532_0
#   markupsafe         pkgs/main/win-64::markupsafe-2.1.1-py39h2bbff1b_0
#   mkl                pkgs/main/win-64::mkl-2021.4.0-haa95532_640
#   mkl-service        pkgs/main/win-64::mkl-service-2.4.0-py39h2bbff1b_0
#   mkl_fft            pkgs/main/win-64::mkl_fft-1.3.1-py39h277e83a_0
#   mkl_random         pkgs/main/win-64::mkl_random-1.2.2-py39hf11a4ad_0
#   multidict          pkgs/main/win-64::multidict-6.0.2-py39h2bbff1b_0
#   numpy              pkgs/main/win-64::numpy-1.23.5-py39h3b20f71_0
#   numpy-base         pkgs/main/win-64::numpy-base-1.23.5-py39h4da318b_0
#   oauthlib           pkgs/main/win-64::oauthlib-3.2.1-py39haa95532_0
#   opt_einsum         pkgs/main/noarch::opt_einsum-3.3.0-pyhd3eb1b0_1
#   packaging          pkgs/main/win-64::packaging-22.0-py39haa95532_0
#   pluggy             pkgs/main/win-64::pluggy-1.0.0-py39haa95532_1
#   pooch              pkgs/main/noarch::pooch-1.4.0-pyhd3eb1b0_0
#   protobuf           pkgs/main/win-64::protobuf-3.14.0-py39hd77b12b_1
#   pyasn1             pkgs/main/noarch::pyasn1-0.4.8-pyhd3eb1b0_0
#   pyasn1-modules     pkgs/main/noarch::pyasn1-modules-0.2.8-py_0
#   pyjwt              pkgs/main/win-64::pyjwt-2.4.0-py39haa95532_0
#   python-flatbuffers pkgs/main/noarch::python-flatbuffers-1.12-pyhd3eb1b0_0
#   requests-oauthlib  pkgs/main/noarch::requests-oauthlib-1.3.0-py_0
#   rsa                pkgs/main/noarch::rsa-4.7.2-pyhd3eb1b0_1
#   ruamel.yaml        pkgs/main/win-64::ruamel.yaml-0.17.21-py39h2bbff1b_0
#   ruamel.yaml.clib   pkgs/main/win-64::ruamel.yaml.clib-0.2.6-py39h2bbff1b_1
#   scipy              pkgs/main/win-64::scipy-1.10.0-py39h321e85e_0
#   snappy             pkgs/main/win-64::snappy-1.1.9-h6c2663c_0
#   tensorboard        pkgs/main/noarch::tensorboard-2.6.0-py_1
#   tensorboard-data-~ pkgs/main/win-64::tensorboard-data-server-0.6.1-py39haa95532_0
#   tensorboard-plugi~ pkgs/main/win-64::tensorboard-plugin-wit-1.8.1-py39haa95532_0
#   tensorflow         pkgs/main/win-64::tensorflow-2.6.0-mkl_py39h31650da_0
#   tensorflow-base    pkgs/main/win-64::tensorflow-base-2.6.0-mkl_py39h9201259_0
#   tensorflow-estima~ pkgs/main/noarch::tensorflow-estimator-2.6.0-pyh7b7c402_0
#   termcolor          pkgs/main/win-64::termcolor-2.1.0-py39haa95532_0
#   toolz              pkgs/main/win-64::toolz-0.12.0-py39haa95532_0
#   typing_extensions  pkgs/main/win-64::typing_extensions-4.4.0-py39haa95532_0
#   werkzeug           pkgs/main/win-64::werkzeug-2.2.2-py39haa95532_0
#   wrapt              pkgs/main/win-64::wrapt-1.14.1-py39h2bbff1b_0
#   yarl               pkgs/main/win-64::yarl-1.8.1-py39h2bbff1b_0
#   zipp               pkgs/main/win-64::zipp-3.11.0-py39haa95532_0
#   zlib               pkgs/main/win-64::zlib-1.2.13-h8cc25b3_0
#
# The following packages will be UPDATED:
#
#   ca-certificates                      2022.3.29-haa95532_1 --> 2023.01.10-haa95532_0
#   certifi                          2021.10.8-py39haa95532_2 --> 2022.12.7-py39haa95532_0
#   conda                               4.12.0-py39haa95532_0 --> 23.1.0-py39haa95532_0
#   openssl                                 1.1.1n-h2bbff1b_0 --> 1.1.1t-h2bbff1b_0
#
# The following packages will be DOWNGRADED:
#
#   wheel                                 0.37.1-pyhd3eb1b0_0 --> 0.35.1-pyhd3eb1b0_0
#
#
#
# Downloading and Extracting Packages
#
# python-flatbuffers-1 | 24 KB     |            |   0%
# python-flatbuffers-1 | 24 KB     | ######7    |  68%
# python-flatbuffers-1 | 24 KB     | ########## | 100%
#
# typing_extensions-4. | 47 KB     |            |   0%
# typing_extensions-4. | 47 KB     | ########## | 100%
# typing_extensions-4. | 47 KB     | ########## | 100%
#
# click-8.0.4          | 155 KB    |            |   0%
# click-8.0.4          | 155 KB    | ########## | 100%
# click-8.0.4          | 155 KB    | ########## | 100%
#
# pyjwt-2.4.0          | 38 KB     |            |   0%
# pyjwt-2.4.0          | 38 KB     | ########## | 100%
# pyjwt-2.4.0          | 38 KB     | ########## | 100%
#
# importlib-metadata-4 | 41 KB     |            |   0%
# importlib-metadata-4 | 41 KB     | ########## | 100%
#
# h5py-3.7.0           | 823 KB    |            |   0%
# h5py-3.7.0           | 823 KB    | ###4       |  35%
# h5py-3.7.0           | 823 KB    | ########## | 100%
# h5py-3.7.0           | 823 KB    | ########## | 100%
#
# markupsafe-2.1.1     | 26 KB     |            |   0%
# markupsafe-2.1.1     | 26 KB     | ########## | 100%
# markupsafe-2.1.1     | 26 KB     | ########## | 100%
#
# tensorflow-2.6.0     | 4 KB      |            |   0%
# tensorflow-2.6.0     | 4 KB      | ########## | 100%
#
# google-auth-oauthlib | 20 KB     |            |   0%
# google-auth-oauthlib | 20 KB     | ########## | 100%
#
# zipp-3.11.0          | 20 KB     |            |   0%
# zipp-3.11.0          | 20 KB     | ########## | 100%
#
# attrs-22.1.0         | 84 KB     |            |   0%
# attrs-22.1.0         | 84 KB     | #####7     |  57%
# attrs-22.1.0         | 84 KB     | ########## | 100%
# attrs-22.1.0         | 84 KB     | ########## | 100%
#
# werkzeug-2.2.2       | 340 KB    |            |   0%
# werkzeug-2.2.2       | 340 KB    | 4          |   5%
# werkzeug-2.2.2       | 340 KB    | #8         |  19%
# werkzeug-2.2.2       | 340 KB    | ###2       |  33%
# werkzeug-2.2.2       | 340 KB    | #####1     |  52%
# werkzeug-2.2.2       | 340 KB    | #######5   |  75%
# werkzeug-2.2.2       | 340 KB    | ########## | 100%
# werkzeug-2.2.2       | 340 KB    | ########## | 100%
#
# mkl_random-1.2.2     | 225 KB    |            |   0%
# mkl_random-1.2.2     | 225 KB    | #4         |  14%
# mkl_random-1.2.2     | 225 KB    | ######4    |  64%
# mkl_random-1.2.2     | 225 KB    | ########## | 100%
# mkl_random-1.2.2     | 225 KB    | ########## | 100%
#
# astor-0.8.1          | 47 KB     |            |   0%
# astor-0.8.1          | 47 KB     | ########## | 100%
# astor-0.8.1          | 47 KB     | ########## | 100%
#
# mkl_fft-1.3.1        | 139 KB    |            |   0%
# mkl_fft-1.3.1        | 139 KB    | ####6      |  46%
# mkl_fft-1.3.1        | 139 KB    | ########## | 100%
# mkl_fft-1.3.1        | 139 KB    | ########## | 100%
#
# ruamel.yaml-0.17.21  | 174 KB    |            |   0%
# ruamel.yaml-0.17.21  | 174 KB    | #8         |  18%
# ruamel.yaml-0.17.21  | 174 KB    | ########## | 100%
# ruamel.yaml-0.17.21  | 174 KB    | ########## | 100%
#
# tensorflow-base-2.6. | 65.1 MB   |            |   0%
# tensorflow-base-2.6. | 65.1 MB   |            |   0%
# tensorflow-base-2.6. | 65.1 MB   |            |   0%
# tensorflow-base-2.6. | 65.1 MB   |            |   1%
# tensorflow-base-2.6. | 65.1 MB   |            |   1%
# tensorflow-base-2.6. | 65.1 MB   | 1          |   1%
# tensorflow-base-2.6. | 65.1 MB   | 1          |   2%
# tensorflow-base-2.6. | 65.1 MB   | 2          |   2%
# tensorflow-base-2.6. | 65.1 MB   | 2          |   3%
# tensorflow-base-2.6. | 65.1 MB   | 3          |   3%
# tensorflow-base-2.6. | 65.1 MB   | 3          |   3%
# tensorflow-base-2.6. | 65.1 MB   | 4          |   4%
# tensorflow-base-2.6. | 65.1 MB   | 4          |   5%
# tensorflow-base-2.6. | 65.1 MB   | 5          |   5%
# tensorflow-base-2.6. | 65.1 MB   | 6          |   6%
# tensorflow-base-2.6. | 65.1 MB   | 7          |   7%
# tensorflow-base-2.6. | 65.1 MB   | 7          |   8%
# tensorflow-base-2.6. | 65.1 MB   | 8          |   9%
# tensorflow-base-2.6. | 65.1 MB   | 9          |  10%
# tensorflow-base-2.6. | 65.1 MB   | #1         |  11%
# tensorflow-base-2.6. | 65.1 MB   | #2         |  12%
# tensorflow-base-2.6. | 65.1 MB   | #3         |  14%
# tensorflow-base-2.6. | 65.1 MB   | #5         |  15%
# tensorflow-base-2.6. | 65.1 MB   | #6         |  17%
# tensorflow-base-2.6. | 65.1 MB   | #8         |  18%
# tensorflow-base-2.6. | 65.1 MB   | #9         |  19%
# tensorflow-base-2.6. | 65.1 MB   | ##1        |  21%
# tensorflow-base-2.6. | 65.1 MB   | ##2        |  23%
# tensorflow-base-2.6. | 65.1 MB   | ##4        |  25%
# tensorflow-base-2.6. | 65.1 MB   | ##7        |  27%
# tensorflow-base-2.6. | 65.1 MB   | ##8        |  29%
# tensorflow-base-2.6. | 65.1 MB   | ###        |  31%
# tensorflow-base-2.6. | 65.1 MB   | ###2       |  32%
# tensorflow-base-2.6. | 65.1 MB   | ###4       |  35%
# tensorflow-base-2.6. | 65.1 MB   | ###6       |  36%
# tensorflow-base-2.6. | 65.1 MB   | ###8       |  38%
# tensorflow-base-2.6. | 65.1 MB   | ###9       |  40%
# tensorflow-base-2.6. | 65.1 MB   | ####       |  41%
# tensorflow-base-2.6. | 65.1 MB   | ####2      |  42%
# tensorflow-base-2.6. | 65.1 MB   | ####4      |  44%
# tensorflow-base-2.6. | 65.1 MB   | ####5      |  46%
# tensorflow-base-2.6. | 65.1 MB   | ####7      |  47%
# tensorflow-base-2.6. | 65.1 MB   | ####8      |  49%
# tensorflow-base-2.6. | 65.1 MB   | #####      |  50%
# tensorflow-base-2.6. | 65.1 MB   | #####1     |  52%
# tensorflow-base-2.6. | 65.1 MB   | #####3     |  53%
# tensorflow-base-2.6. | 65.1 MB   | #####4     |  54%
# tensorflow-base-2.6. | 65.1 MB   | #####6     |  57%
# tensorflow-base-2.6. | 65.1 MB   | #####8     |  58%
# tensorflow-base-2.6. | 65.1 MB   | #####9     |  60%
# tensorflow-base-2.6. | 65.1 MB   | ######     |  61%
# tensorflow-base-2.6. | 65.1 MB   | ######2    |  62%
# tensorflow-base-2.6. | 65.1 MB   | ######3    |  63%
# tensorflow-base-2.6. | 65.1 MB   | ######4    |  65%
# tensorflow-base-2.6. | 65.1 MB   | ######6    |  66%
# tensorflow-base-2.6. | 65.1 MB   | ######7    |  67%
# tensorflow-base-2.6. | 65.1 MB   | ######8    |  69%
# tensorflow-base-2.6. | 65.1 MB   | #######    |  70%
# tensorflow-base-2.6. | 65.1 MB   | #######1   |  71%
# tensorflow-base-2.6. | 65.1 MB   | #######3   |  73%
# tensorflow-base-2.6. | 65.1 MB   | #######4   |  74%
# tensorflow-base-2.6. | 65.1 MB   | #######5   |  76%
# tensorflow-base-2.6. | 65.1 MB   | #######7   |  77%
# tensorflow-base-2.6. | 65.1 MB   | #######8   |  79%
# tensorflow-base-2.6. | 65.1 MB   | ########   |  80%
# tensorflow-base-2.6. | 65.1 MB   | ########2  |  82%
# tensorflow-base-2.6. | 65.1 MB   | ########3  |  84%
# tensorflow-base-2.6. | 65.1 MB   | ########5  |  85%
# tensorflow-base-2.6. | 65.1 MB   | ########7  |  87%
# tensorflow-base-2.6. | 65.1 MB   | ########8  |  89%
# tensorflow-base-2.6. | 65.1 MB   | #########  |  91%
# tensorflow-base-2.6. | 65.1 MB   | #########2 |  93%
# tensorflow-base-2.6. | 65.1 MB   | #########4 |  95%
# tensorflow-base-2.6. | 65.1 MB   | #########6 |  96%
# tensorflow-base-2.6. | 65.1 MB   | #########8 |  98%
# tensorflow-base-2.6. | 65.1 MB   | ########## | 100%
#
# markdown-3.4.1       | 148 KB    |            |   0%
# markdown-3.4.1       | 148 KB    | #          |  11%
# markdown-3.4.1       | 148 KB    | #####4     |  54%
# markdown-3.4.1       | 148 KB    | ########## | 100%
# markdown-3.4.1       | 148 KB    | ########## | 100%
#
# yarl-1.8.1           | 80 KB     |            |   0%
# yarl-1.8.1           | 80 KB     | ###9       |  40%
# yarl-1.8.1           | 80 KB     | ########## | 100%
# yarl-1.8.1           | 80 KB     | ########## | 100%
#
# scipy-1.10.0         | 18.7 MB   |            |   0%
# scipy-1.10.0         | 18.7 MB   |            |   0%
# scipy-1.10.0         | 18.7 MB   |            |   1%
# scipy-1.10.0         | 18.7 MB   | 1          |   2%
# scipy-1.10.0         | 18.7 MB   | 2          |   2%
# scipy-1.10.0         | 18.7 MB   | 3          |   3%
# scipy-1.10.0         | 18.7 MB   | 3          |   4%
# scipy-1.10.0         | 18.7 MB   | 4          |   4%
# scipy-1.10.0         | 18.7 MB   | 4          |   5%
# scipy-1.10.0         | 18.7 MB   | 5          |   6%
# scipy-1.10.0         | 18.7 MB   | 6          |   7%
# scipy-1.10.0         | 18.7 MB   | 7          |   7%
# scipy-1.10.0         | 18.7 MB   | 8          |   9%
# scipy-1.10.0         | 18.7 MB   | 9          |   9%
# scipy-1.10.0         | 18.7 MB   | #          |  10%
# scipy-1.10.0         | 18.7 MB   | #1         |  11%
# scipy-1.10.0         | 18.7 MB   | #2         |  13%
# scipy-1.10.0         | 18.7 MB   | #3         |  14%
# scipy-1.10.0         | 18.7 MB   | #5         |  16%
# scipy-1.10.0         | 18.7 MB   | #7         |  17%
# scipy-1.10.0         | 18.7 MB   | #9         |  19%
# scipy-1.10.0         | 18.7 MB   | ##         |  21%
# scipy-1.10.0         | 18.7 MB   | ##3        |  23%
# scipy-1.10.0         | 18.7 MB   | ##4        |  25%
# scipy-1.10.0         | 18.7 MB   | ##6        |  27%
# scipy-1.10.0         | 18.7 MB   | ##9        |  29%
# scipy-1.10.0         | 18.7 MB   | ###2       |  32%
# scipy-1.10.0         | 18.7 MB   | ###4       |  35%
# scipy-1.10.0         | 18.7 MB   | ###7       |  37%
# scipy-1.10.0         | 18.7 MB   | ####       |  41%
# scipy-1.10.0         | 18.7 MB   | ####4      |  44%
# scipy-1.10.0         | 18.7 MB   | ####7      |  47%
# scipy-1.10.0         | 18.7 MB   | #####1     |  51%
# scipy-1.10.0         | 18.7 MB   | #####5     |  55%
# scipy-1.10.0         | 18.7 MB   | #####8     |  59%
# scipy-1.10.0         | 18.7 MB   | ######5    |  65%
# scipy-1.10.0         | 18.7 MB   | ######9    |  70%
# scipy-1.10.0         | 18.7 MB   | #######3   |  74%
# scipy-1.10.0         | 18.7 MB   | ########   |  81%
# scipy-1.10.0         | 18.7 MB   | ########5  |  85%
# scipy-1.10.0         | 18.7 MB   | ########9  |  90%
# scipy-1.10.0         | 18.7 MB   | #########4 |  94%
# scipy-1.10.0         | 18.7 MB   | #########8 |  99%
# scipy-1.10.0         | 18.7 MB   | ########## | 100%
#
# toolz-0.12.0         | 106 KB    |            |   0%
# toolz-0.12.0         | 106 KB    | #5         |  15%
# toolz-0.12.0         | 106 KB    | #######5   |  76%
# toolz-0.12.0         | 106 KB    | ########## | 100%
#
# wrapt-1.14.1         | 49 KB     |            |   0%
# wrapt-1.14.1         | 49 KB     | ########## | 100%
# wrapt-1.14.1         | 49 KB     | ########## | 100%
#
# tensorboard-data-ser | 17 KB     |            |   0%
# tensorboard-data-ser | 17 KB     | ########## | 100%
# tensorboard-data-ser | 17 KB     | ########## | 100%
#
# packaging-22.0       | 67 KB     |            |   0%
# packaging-22.0       | 67 KB     | ########## | 100%
#
# icu-68.1             | 11.0 MB   |            |   0%
# icu-68.1             | 11.0 MB   | 2          |   2%
# icu-68.1             | 11.0 MB   | 4          |   5%
# icu-68.1             | 11.0 MB   | #1         |  12%
# icu-68.1             | 11.0 MB   | #7         |  17%
# icu-68.1             | 11.0 MB   | ##2        |  22%
# icu-68.1             | 11.0 MB   | ##8        |  28%
# icu-68.1             | 11.0 MB   | ###3       |  34%
# icu-68.1             | 11.0 MB   | ###8       |  39%
# icu-68.1             | 11.0 MB   | #####      |  51%
# icu-68.1             | 11.0 MB   | #####7     |  57%
# icu-68.1             | 11.0 MB   | ######3    |  64%
# icu-68.1             | 11.0 MB   | #######4   |  74%
# icu-68.1             | 11.0 MB   | ########1  |  82%
# icu-68.1             | 11.0 MB   | #########1 |  91%
# icu-68.1             | 11.0 MB   | ########## | 100%
# icu-68.1             | 11.0 MB   | ########## | 100%
#
# blinker-1.4          | 23 KB     |            |   0%
# blinker-1.4          | 23 KB     | ########## | 100%
#
# conda-23.1.0         | 946 KB    |            |   0%
# conda-23.1.0         | 946 KB    | #####7     |  58%
# conda-23.1.0         | 946 KB    | ########## | 100%
#
# protobuf-3.14.0      | 241 KB    |            |   0%
# protobuf-3.14.0      | 241 KB    | 6          |   7%
# protobuf-3.14.0      | 241 KB    | ###9       |  40%
# protobuf-3.14.0      | 241 KB    | #######9   |  80%
# protobuf-3.14.0      | 241 KB    | ########## | 100%
#
# abseil-cpp-20210324. | 1.6 MB    |            |   0%
# abseil-cpp-20210324. | 1.6 MB    |            |   1%
# abseil-cpp-20210324. | 1.6 MB    | ###6       |  37%
# abseil-cpp-20210324. | 1.6 MB    | ########## | 100%
# abseil-cpp-20210324. | 1.6 MB    | ########## | 100%
#
# numpy-base-1.23.5    | 6.0 MB    |            |   0%
# numpy-base-1.23.5    | 6.0 MB    | 2          |   2%
# numpy-base-1.23.5    | 6.0 MB    | #8         |  19%
# numpy-base-1.23.5    | 6.0 MB    | ##9        |  29%
# numpy-base-1.23.5    | 6.0 MB    | ####8      |  49%
# numpy-base-1.23.5    | 6.0 MB    | ######3    |  64%
# numpy-base-1.23.5    | 6.0 MB    | #######8   |  78%
# numpy-base-1.23.5    | 6.0 MB    | #########1 |  91%
# numpy-base-1.23.5    | 6.0 MB    | ########## | 100%
#
# frozenlist-1.3.3     | 40 KB     |            |   0%
# frozenlist-1.3.3     | 40 KB     | ########## | 100%
#
# oauthlib-3.2.1       | 194 KB    |            |   0%
# oauthlib-3.2.1       | 194 KB    | ########## | 100%
# oauthlib-3.2.1       | 194 KB    | ########## | 100%
#
# multidict-6.0.2      | 46 KB     |            |   0%
# multidict-6.0.2      | 46 KB     | ########## | 100%
# multidict-6.0.2      | 46 KB     | ########## | 100%
#
# pluggy-1.0.0         | 29 KB     |            |   0%
# pluggy-1.0.0         | 29 KB     | ########## | 100%
#
# mkl-service-2.4.0    | 51 KB     |            |   0%
# mkl-service-2.4.0    | 51 KB     | ########## | 100%
# mkl-service-2.4.0    | 51 KB     | ########## | 100%
#
# absl-py-1.3.0        | 171 KB    |            |   0%
# absl-py-1.3.0        | 171 KB    | ######5    |  65%
# absl-py-1.3.0        | 171 KB    | ########## | 100%
#
# certifi-2022.12.7    | 149 KB    |            |   0%
# certifi-2022.12.7    | 149 KB    | #####3     |  54%
# certifi-2022.12.7    | 149 KB    | #######5   |  75%
# certifi-2022.12.7    | 149 KB    | ########5  |  86%
# certifi-2022.12.7    | 149 KB    | ########## | 100%
# certifi-2022.12.7    | 149 KB    | ########## | 100%
#
# grpcio-1.42.0        | 1.9 MB    |            |   0%
# grpcio-1.42.0        | 1.9 MB    |            |   1%
# grpcio-1.42.0        | 1.9 MB    | 2          |   3%
# grpcio-1.42.0        | 1.9 MB    | 4          |   4%
# grpcio-1.42.0        | 1.9 MB    | 6          |   7%
# grpcio-1.42.0        | 1.9 MB    | 9          |   9%
# grpcio-1.42.0        | 1.9 MB    | #3         |  14%
# grpcio-1.42.0        | 1.9 MB    | #9         |  19%
# grpcio-1.42.0        | 1.9 MB    | ##7        |  28%
# grpcio-1.42.0        | 1.9 MB    | ###7       |  37%
# grpcio-1.42.0        | 1.9 MB    | ####5      |  46%
# grpcio-1.42.0        | 1.9 MB    | #####6     |  57%
# grpcio-1.42.0        | 1.9 MB    | ######7    |  68%
# grpcio-1.42.0        | 1.9 MB    | #######9   |  79%
# grpcio-1.42.0        | 1.9 MB    | #########2 |  93%
# grpcio-1.42.0        | 1.9 MB    | ########## | 100%
#
# aiohttp-3.8.3        | 415 KB    |            |   0%
# aiohttp-3.8.3        | 415 KB    | ###        |  31%
# aiohttp-3.8.3        | 415 KB    | ######1    |  62%
# aiohttp-3.8.3        | 415 KB    | ########## | 100%
#
# libprotobuf-3.14.0   | 1.9 MB    |            |   0%
# libprotobuf-3.14.0   | 1.9 MB    |            |   1%
# libprotobuf-3.14.0   | 1.9 MB    | 3          |   3%
# libprotobuf-3.14.0   | 1.9 MB    | 6          |   7%
# libprotobuf-3.14.0   | 1.9 MB    | #          |  11%
# libprotobuf-3.14.0   | 1.9 MB    | #6         |  17%
# libprotobuf-3.14.0   | 1.9 MB    | ##5        |  25%
# libprotobuf-3.14.0   | 1.9 MB    | ###6       |  36%
# libprotobuf-3.14.0   | 1.9 MB    | #####1     |  51%
# libprotobuf-3.14.0   | 1.9 MB    | ######8    |  69%
# libprotobuf-3.14.0   | 1.9 MB    | ########8  |  89%
# libprotobuf-3.14.0   | 1.9 MB    | ########## | 100%
#
# numpy-1.23.5         | 11 KB     |            |   0%
# numpy-1.23.5         | 11 KB     | ########## | 100%
#
# async-timeout-4.0.2  | 12 KB     |            |   0%
# async-timeout-4.0.2  | 12 KB     | ########## | 100%
#
# wheel-0.35.1         | 38 KB     |            |   0%
# wheel-0.35.1         | 38 KB     | ########## | 100%
# wheel-0.35.1         | 38 KB     | ########## | 100%
#
# tensorflow-estimator | 267 KB    |            |   0%
# tensorflow-estimator | 267 KB    | #########5 |  96%
# tensorflow-estimator | 267 KB    | ########## | 100%
#
# ruamel.yaml.clib-0.2 | 101 KB    |            |   0%
# ruamel.yaml.clib-0.2 | 101 KB    | ########## | 100%
# ruamel.yaml.clib-0.2 | 101 KB    | ########## | 100%
#
# tensorboard-plugin-w | 671 KB    |            |   0%
# tensorboard-plugin-w | 671 KB    | ###8       |  38%
# tensorboard-plugin-w | 671 KB    | ########## | 100%
# tensorboard-plugin-w | 671 KB    | ########## | 100%
#
# tensorboard-2.6.0    | 4.9 MB    |            |   0%
# tensorboard-2.6.0    | 4.9 MB    | 6          |   6%
# tensorboard-2.6.0    | 4.9 MB    | #6         |  17%
# tensorboard-2.6.0    | 4.9 MB    | ##7        |  28%
# tensorboard-2.6.0    | 4.9 MB    | ###9       |  40%
# tensorboard-2.6.0    | 4.9 MB    | #####2     |  53%
# tensorboard-2.6.0    | 4.9 MB    | ######6    |  66%
# tensorboard-2.6.0    | 4.9 MB    | ########2  |  83%
# tensorboard-2.6.0    | 4.9 MB    | ########## | 100%
# tensorboard-2.6.0    | 4.9 MB    | ########## | 100%
#
# termcolor-2.1.0      | 12 KB     |            |   0%
# termcolor-2.1.0      | 12 KB     | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done

# %%
conda install keras
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\tuana\miniconda3
#
#   added / updated specs:
#     - keras
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     keras-2.6.0                |     pyhd3eb1b0_0         721 KB
#     ------------------------------------------------------------
#                                            Total:         721 KB
#
# The following NEW packages will be INSTALLED:
#
#   keras              pkgs/main/noarch::keras-2.6.0-pyhd3eb1b0_0
#
#
#
# Downloading and Extracting Packages
#
# keras-2.6.0          | 721 KB    |            |   0%
# keras-2.6.0          | 721 KB    | 2          |   2%
# keras-2.6.0          | 721 KB    | 8          |   9%
# keras-2.6.0          | 721 KB    | ###3       |  33%
# keras-2.6.0          | 721 KB    | ######8    |  69%
# keras-2.6.0          | 721 KB    | ########## | 100%
# keras-2.6.0          | 721 KB    | ########## | 100%
#
#
#
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install -U scikit-learn
# Out:
# Collecting scikit-learn
#   Downloading scikit_learn-1.2.1-cp39-cp39-win_amd64.whl (8.4 MB)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\tuana\miniconda3\lib\site-packages (from scikit-learn) (1.23.5)
# Collecting threadpoolctl>=2.0.0
#   Using cached threadpoolctl-3.1.0-py3-none-any.whl (14 kB)
# Collecting joblib>=1.1.1
#   Using cached joblib-1.2.0-py3-none-any.whl (297 kB)
# Requirement already satisfied: scipy>=1.3.2 in c:\users\tuana\miniconda3\lib\site-packages (from scikit-learn) (1.10.0)
# Installing collected packages: threadpoolctl, joblib, scikit-learn
# Successfully installed joblib-1.2.0 scikit-learn-1.2.1 threadpoolctl-3.1.0
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -qdm (c:\users\tuana\miniconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -qdm (c:\users\tuana\miniconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -qdm (c:\users\tuana\miniconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -qdm (c:\users\tuana\miniconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -qdm (c:\users\tuana\miniconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -qdm (c:\users\tuana\miniconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -qdm (c:\users\tuana\miniconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -qdm (c:\users\tuana\miniconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -qdm (c:\users\tuana\miniconda3\lib\site-packages)

# %%
import pandas as pd
import numpy as np
import keras
import cv2
from keras.preprocessing.image import ImageDataGenerator
from sklearn.preprocessing import LabelBinarizer
from keras.models import Sequential
from keras import optimizers
from keras import backend as K
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Conv2D, MaxPooling2D, BatchNormalization
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# %%
train  = pd.read_csv("../input/sign-language-mnist/sign_mnist_train.csv")
test = pd.read_csv("../input/sign-language-mnist/sign_mnist_test.csv")

# %%
train.head()
